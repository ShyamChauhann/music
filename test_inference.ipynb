# %%
    from pipeline import build_audiosep, inference
    import torch

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model = build_audiosep(
        config_yaml='config/audiosep_base.yaml',
        checkpoint_path='checkpoint/audiosep_base_4M_steps.ckpt',
        device=device
    )

    audio_file = 'examples/test_clip.wav'
    text = 'vocals'
    output_file = 'output_separated.wav'

    inference(model, audio_file, text, output_file, device)

    print("✅ Inference complete! Output saved to:", output_file)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from pipeline import build_audiosep, inference
#       2 import torch
#       4 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#
# File D:\AudioSep-main\pipeline.py:5
#       3 import torch
#       4 import numpy as np
# ----> 5 import librosa
#       6 from scipy.io.wavfile import write
#       7 from utils import ignore_warnings, parse_yaml, load_ss_model
#
# ModuleNotFoundError: No module named 'librosa'
