# %%
from pipeline import build_audiosep, inference
import torch

# Use GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Build the model
model = build_audiosep(
    config_yaml='config/audiosep_base.yaml',
    checkpoint_path='checkpoint/audiosep_base_4M_steps.ckpt',
    device=device
)

# Paths
audio_file = 'examples/example.wav'   # Put a test WAV file here (32 kHz)
text = 'a man speaking'               # Describe the sound to extract
output_file = 'output_separated.wav'  # Output file path

# Run inference
inference(model, audio_file, text, output_file, device)

print("✅ Inference complete! Output saved to:", output_file)
